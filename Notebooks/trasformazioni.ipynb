# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA

# %%
df = pd.read_csv(r"features.txt", sep=" ", header=None)
df
# Out:
#        0                                     1
# 0      1                     tBodyAcc-mean()-X
# 1      2                     tBodyAcc-mean()-Y
# 2      3                     tBodyAcc-mean()-Z
# 3      4                      tBodyAcc-std()-X
# 4      5                      tBodyAcc-std()-Y
# ..   ...                                   ...
# 556  557      angle(tBodyGyroMean,gravityMean)
# 557  558  angle(tBodyGyroJerkMean,gravityMean)
# 558  559                  angle(X,gravityMean)
# 559  560                  angle(Y,gravityMean)
# 560  561                  angle(Z,gravityMean)
#
# [561 rows x 2 columns]

# %%
df.rename({1: 'X'}, axis=1, inplace=True)

# %%
l = list(df["X"].values)
l
# Out:
# ['tBodyAcc-mean()-X',
#  'tBodyAcc-mean()-Y',
#  'tBodyAcc-mean()-Z',
#  'tBodyAcc-std()-X',
#  'tBodyAcc-std()-Y',
#  'tBodyAcc-std()-Z',
#  'tBodyAcc-mad()-X',
#  'tBodyAcc-mad()-Y',
#  'tBodyAcc-mad()-Z',
#  'tBodyAcc-max()-X',
#  'tBodyAcc-max()-Y',
#  'tBodyAcc-max()-Z',
#  'tBodyAcc-min()-X',
#  'tBodyAcc-min()-Y',
#  'tBodyAcc-min()-Z',
#  'tBodyAcc-sma()',
#  'tBodyAcc-energy()-X',
#  'tBodyAcc-energy()-Y',
#  'tBodyAcc-energy()-Z',
#  'tBodyAcc-iqr()-X',
#  'tBodyAcc-iqr()-Y',
#  'tBodyAcc-iqr()-Z',
#  'tBodyAcc-entropy()-X',
#  'tBodyAcc-entropy()-Y',
#  'tBodyAcc-entropy()-Z',
#  'tBodyAcc-arCoeff()-X,1',
#  'tBodyAcc-arCoeff()-X,2',
#  'tBodyAcc-arCoeff()-X,3',
#  'tBodyAcc-arCoeff()-X,4',
#  'tBodyAcc-arCoeff()-Y,1',
#  'tBodyAcc-arCoeff()-Y,2',
#  'tBodyAcc-arCoeff()-Y,3',
#  'tBodyAcc-arCoeff()-Y,4',
#  'tBodyAcc-arCoeff()-Z,1',
#  'tBodyAcc-arCoeff()-Z,2',
#  'tBodyAcc-arCoeff()-Z,3',
#  'tBodyAcc-arCoeff()-Z,4',
#  'tBodyAcc-correlation()-X,Y',
# ...

# %%
df2 = pd.read_fwf(r"C:\Users\daddu\OneDrive\Desktop\MAGISTRALE\Data Mining\DM2\UCI HAR Dataset\train\X_train.txt", header=None)
df2
# Out:
#            0         1         2         3         4         5         6    \
# 0     0.288585 -0.020294 -0.132905 -0.995279 -0.983111 -0.913526 -0.995112
# 1     0.278419 -0.016411 -0.123520 -0.998245 -0.975300 -0.960322 -0.998807
# 2     0.279653 -0.019467 -0.113462 -0.995380 -0.967187 -0.978944 -0.996520
# 3     0.279174 -0.026201 -0.123283 -0.996091 -0.983403 -0.990675 -0.997099
# 4     0.276629 -0.016570 -0.115362 -0.998139 -0.980817 -0.990482 -0.998321
# ...        ...       ...       ...       ...       ...       ...       ...
# 7347  0.299665 -0.057193 -0.181233 -0.195387  0.039905  0.077078 -0.282301
# 7348  0.273853 -0.007749 -0.147468 -0.235309  0.004816  0.059280 -0.322552
# 7349  0.273387 -0.017011 -0.045022 -0.218218 -0.103822  0.274533 -0.304515
# 7350  0.289654 -0.018843 -0.158281 -0.219139 -0.111412  0.268893 -0.310487
# 7351  0.351503 -0.012423 -0.203867 -0.269270 -0.087212  0.177404 -0.377404
#
# ...

# %%
for i in range(len(l)):
    df2.rename({i: str(l[i])}, axis=1, inplace=True)

# %%
df2
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0              0.288585          -0.020294          -0.132905
# 1              0.278419          -0.016411          -0.123520
# 2              0.279653          -0.019467          -0.113462
# 3              0.279174          -0.026201          -0.123283
# 4              0.276629          -0.016570          -0.115362
# ...                 ...                ...                ...
# 7347           0.299665          -0.057193          -0.181233
# 7348           0.273853          -0.007749          -0.147468
# 7349           0.273387          -0.017011          -0.045022
# 7350           0.289654          -0.018843          -0.158281
# 7351           0.351503          -0.012423          -0.203867
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 0            -0.995279         -0.983111         -0.913526         -0.995112
# ...

# %%
df3 = pd.read_fwf(r"C:\Users\daddu\OneDrive\Desktop\MAGISTRALE\Data Mining\DM2\UCI HAR Dataset\test\X_test.txt", header=None)
df3
# Out:
#            0         1         2         3         4         5         6    \
# 0     0.257178 -0.023285 -0.014654 -0.938404 -0.920091 -0.667683 -0.952501
# 1     0.286027 -0.013163 -0.119083 -0.975415 -0.967458 -0.944958 -0.986799
# 2     0.275485 -0.026050 -0.118152 -0.993819 -0.969926 -0.962748 -0.994403
# 3     0.270298 -0.032614 -0.117520 -0.994743 -0.973268 -0.967091 -0.995274
# 4     0.274833 -0.027848 -0.129527 -0.993852 -0.967445 -0.978295 -0.994111
# ...        ...       ...       ...       ...       ...       ...       ...
# 2942  0.310155 -0.053391 -0.099109 -0.287866 -0.140589 -0.215088 -0.356083
# 2943  0.363385 -0.039214 -0.105915 -0.305388  0.028148 -0.196373 -0.373540
# 2944  0.349966  0.030077 -0.115788 -0.329638 -0.042143 -0.250181 -0.388017
# 2945  0.237594  0.018467 -0.096499 -0.323114 -0.229775 -0.207574 -0.392380
# 2946  0.153627 -0.018437 -0.137018 -0.330046 -0.195253 -0.164339 -0.430974
#
# ...

# %%
for i in range(len(l)):
    df3.rename({i: str(l[i])}, axis=1, inplace=True)
df3
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0              0.257178          -0.023285          -0.014654
# 1              0.286027          -0.013163          -0.119083
# 2              0.275485          -0.026050          -0.118152
# 3              0.270298          -0.032614          -0.117520
# 4              0.274833          -0.027848          -0.129527
# ...                 ...                ...                ...
# 2942           0.310155          -0.053391          -0.099109
# 2943           0.363385          -0.039214          -0.105915
# 2944           0.349966           0.030077          -0.115788
# 2945           0.237594           0.018467          -0.096499
# 2946           0.153627          -0.018437          -0.137018
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 0            -0.938404         -0.920091         -0.667683         -0.952501
# ...

# %%
df4 = pd.read_fwf(r"C:\Users\daddu\OneDrive\Desktop\MAGISTRALE\Data Mining\DM2\UCI HAR Dataset\test\y_test.txt", header=None)
df4.rename({0: 'label'}, axis=1, inplace=True)
df4.head()
# Out:
#    label
# 0      5
# 1      5
# 2      5
# 3      5
# 4      5

# %%
df5 = pd.read_fwf(r"C:\Users\daddu\OneDrive\Desktop\MAGISTRALE\Data Mining\DM2\UCI HAR Dataset\train\y_train.txt", header=None)
df5.rename({0: 'label'}, axis=1, inplace=True)
df5
# Out:
#       label
# 0         5
# 1         5
# 2         5
# 3         5
# 4         5
# ...     ...
# 7347      2
# 7348      2
# 7349      2
# 7350      2
# 7351      2
#
# [7352 rows x 1 columns]

# %%
df3["label"] = df4["label"]
df2["label"] = df5["label"]

# %%
df2
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0              0.288585          -0.020294          -0.132905
# 1              0.278419          -0.016411          -0.123520
# 2              0.279653          -0.019467          -0.113462
# 3              0.279174          -0.026201          -0.123283
# 4              0.276629          -0.016570          -0.115362
# ...                 ...                ...                ...
# 7347           0.299665          -0.057193          -0.181233
# 7348           0.273853          -0.007749          -0.147468
# 7349           0.273387          -0.017011          -0.045022
# 7350           0.289654          -0.018843          -0.158281
# 7351           0.351503          -0.012423          -0.203867
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 0            -0.995279         -0.983111         -0.913526         -0.995112
# ...

# %%
df3
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0              0.257178          -0.023285          -0.014654
# 1              0.286027          -0.013163          -0.119083
# 2              0.275485          -0.026050          -0.118152
# 3              0.270298          -0.032614          -0.117520
# 4              0.274833          -0.027848          -0.129527
# ...                 ...                ...                ...
# 2942           0.310155          -0.053391          -0.099109
# 2943           0.363385          -0.039214          -0.105915
# 2944           0.349966           0.030077          -0.115788
# 2945           0.237594           0.018467          -0.096499
# 2946           0.153627          -0.018437          -0.137018
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 0            -0.938404         -0.920091         -0.667683         -0.952501
# ...

# %%
df3.to_csv("X_Test.csv")
df2.to_csv("X_Train.csv")

# %%
df2["label"].value_counts()
# Out:
# 6    1407
# 5    1374
# 4    1286
# 1    1226
# 2    1073
# 3     986
# Name: label, dtype: int64

# %%
df3["label"].value_counts()
# Out:
# 6    537
# 5    532
# 1    496
# 4    491
# 2    471
# 3    420
# Name: label, dtype: int64

# %%
"""df2["label"] = df2["label"].map({1:"WALKING",
                                 2:"WALKING_UPSTAIRS",
                                 3:"WALKING_DOWNSTAIRS",
                                 4:"SITTING",
                                 5:"STANDING",
                                 6:"LAYING"})

df3["label"] = df3["label"].map({1:"WALKING",
                                 2:"WALKING_UPSTAIRS",
                                 3:"WALKING_DOWNSTAIRS",
                                 4:"SITTING",
                                 5:"STANDING",
                                 6:"LAYING"})"""

# %%
df3.to_csv("Test_Labeled.csv")
df2.to_csv("Train_Labeled.csv")

# %%
dfPCA = df2

# %%
dfPCA
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0              0.288585          -0.020294          -0.132905
# 1              0.278419          -0.016411          -0.123520
# 2              0.279653          -0.019467          -0.113462
# 3              0.279174          -0.026201          -0.123283
# 4              0.276629          -0.016570          -0.115362
# ...                 ...                ...                ...
# 7347           0.299665          -0.057193          -0.181233
# 7348           0.273853          -0.007749          -0.147468
# 7349           0.273387          -0.017011          -0.045022
# 7350           0.289654          -0.018843          -0.158281
# 7351           0.351503          -0.012423          -0.203867
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 0            -0.995279         -0.983111         -0.913526         -0.995112
# ...

# %%
y = dfPCA.pop("label")

# %%
pca = PCA(n_components=10)
df_pca = pd.DataFrame(pca.fit_transform(dfPCA))
df_pca
# Out:
#              0         1         2         3         4         5         6  \
# 0    -5.516299 -0.288581 -1.532411  1.396307  1.352158 -0.224078  0.577675
# 1    -5.531271 -0.080497 -1.926008  0.699221  0.636841  0.767080 -0.577650
# 2    -5.470755  0.289892 -2.144259  0.539919  0.178696 -0.038136  0.059037
# 3    -5.673483  0.898107 -2.017040  0.186468  0.757887  1.093214 -0.228587
# 4    -5.745261  1.164046 -2.138468  0.226609  0.465141  0.468474 -0.136525
# ...        ...       ...       ...       ...       ...       ...       ...
# 7347  6.259530 -2.629991  0.444511  1.449846 -0.842235 -0.207079 -1.353039
# 7348  5.787780 -2.432936  0.458920  1.680906 -0.916937 -0.343667 -1.254831
# 7349  5.863134 -3.079156  0.666184  2.236059 -0.608485  0.441191 -0.968118
# 7350  5.426352 -3.425078  0.665125  1.989150 -0.715452  0.505096 -1.421537
# 7351  5.503845 -2.782966  0.001389  1.360802 -0.878340 -0.050902 -0.912995
#
#              7         8         9
# ...

# %%
import matplotlib.pyplot as plt
pd.DataFrame(pca.explained_variance_ratio_).plot.bar()
plt.legend('')
plt.xlabel('Principal Components')
plt.ylabel('Explained Varience');

# %%
pca = PCA().fit(dfPCA)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance');

# %%
def quoziente(a,b):
    check = isinstance(a/b, int)
    if not check:
        return int(a/b)
    return a/b

quoziente(10,6)

def modulo(a,b):
    check = isinstance(a/b, float)
    if check:
        return int(abs(a)-abs(b))
    return abs(a)-abs(b)

modulo(10,-6)
# Out:
# 4

# %%
df10 = pd.read_fwf(r"C:\Users\daddu\OneDrive\Desktop\MAGISTRALE\Data Mining\DM2\UCI HAR Dataset\test\subject_test.txt", header=None)
df10[0].value_counts()
# Out:
# 1    1305
# 2    1037
# 4     317
# 9     288
# Name: 0, dtype: int64
